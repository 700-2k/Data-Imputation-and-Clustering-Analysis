# %%
    from src import analysis

# %%
data = analysis.Dataset("C:\\Users\\VLAD\\prog\\Data-Imputation-and-Clustering-Analysis\\out\\recovered_groups\\small\\3.xlsx")

# %% [markdown]
# # Count mean, median and mode

# %%
data.count_all()
# Out:
# c:\Users\VLAD\prog\Data-Imputation-and-Clustering-Analysis\src\analysis.py:107: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   numeric = s_no_na.view('int64')
#                               store_name                     date-time  \
# mean    Лента (Обводного канала, 118 к7) 2022-11-11 09:17:27.811073024
# median  Лента (Обводного канала, 118 к7) 2022-11-11 20:24:00.000000000
# mode                   DNS (МЕГА Парнас) 2022-08-11 11:19:00.000000000
#
#               coordinates       categories          brands       price  \
# mean    30.36064,59.92741     Овощи свежие  Princess Noori  9732.56469
# median  30.36064,59.92741       Пауэрбанки        Plitonit   908.00000
# mode    30.36064,59.92741  Флеш‑накопители          Adidas   908.00000
#
#             cards_number  number_of_products receipt_id    total_cost
# mean    4100005675262021             4.49545       №223  44267.667111
# ...

# %% [markdown]
# # Ananlyse stores feature

# %%
data.draw_hist_store()

# %% [markdown]
# # Analyse date-time feature

# %%
data.draw_hist_date()

# %% [markdown]
# # Analyse coordinates feature

# %%
data.draw_hist_coords()

# %% [markdown]
# # Analyse categories feature

# %%
data.draw_hist_cats()

# %% [markdown]
# # Analyse brands feature

# %%
data.draw_hist_brand()

# %%
data.draw_hist_top_brands()

# %%
data.draw_hist_bottom_brands()

# %% [markdown]
# # Analyse price feature

# %%
data.draw_hist_price()

# %% [markdown]
# # Analyse card number feature

# %%
data.count_unique('cards_number')
# Out:
# count      7470.0
# mean     4.016198
# std      2.345651
# min           1.0
# 25%           3.0
# 50%           4.0
# 75%           5.0
# max         166.0
# Name: count, dtype: Float64

# %% [markdown]
# # Analyse number of products feature

# %%
data.draw_hist_num_products()

# %% [markdown]
# # Analyse receipt id feature

# %%
data.analyse_receipt_id()
# Out:
# Unique number: 287, Number of rows: 30001
# Highest number of unique receipt id for stores:
# store_name
# DNS (МЕГА Парнас)                         284
# DNS (ТРК Лиговъ, Лиговский 153)           262
# Finn Flare (ТРЦ Охта Молл)                258
# Gloria Jeans (ТРЦ Галерея)                251
# Hockey Club (Российский пр., 6, стр.1)    264
# Name: receipt_id, dtype: int64

# %% [markdown]
# # Analyse total cost feature

# %%
data.draw_hist_total_cost()
