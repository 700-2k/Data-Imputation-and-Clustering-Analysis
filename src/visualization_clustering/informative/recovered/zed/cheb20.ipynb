# %%
from src import analysis

# %%
analysis.inf_cluster_chebyshev("C:\\Users\\VLAD\\prog\\Data-Imputation-and-Clustering-Analysis\\out\\recovered_zet\\small\\20.xlsx")
# Out:
# === Кластер 0 (n=29416) ===
#
# ЧИСЛОВЫЕ ПРИЗНАКИ (describe):
#               count          mean           std   min     25%          50%  \
# price       29416.0   6139.928394  18208.352629  20.0   223.0  1027.000000
# total_cost  29416.0  35622.509667  72019.991795  56.0  1072.0  6827.878929
#
#                 75%       max
# price        3373.0  161401.0
# total_cost  26376.0  566004.0
#
# КАТЕГОРИАЛЬНЫЕ ПРИЗНАКИ (top значения):
#
# store_name:
# store_name
# Перекрёсток (ТРЦ Галерея)           1289
# ВкусВилл (ул. Олеко Дундича, 33)    1112
# О'КЕЙ (пр. Большевиков, 10 к1)      1110
# Name: count, dtype: int64
#
# brands:
# brands
# Sony      619
# Adidas    614
# Weber     577
# Name: count, dtype: int64
#
# cards_number:
# cards_number
# 2200024318558567    164
# 4270008569190014     63
# 2200023904511710     59
# Name: count, dtype: Int64
#
# === Кластер 1 (n=284) ===
#
# ЧИСЛОВЫЕ ПРИЗНАКИ (describe):
# ...
