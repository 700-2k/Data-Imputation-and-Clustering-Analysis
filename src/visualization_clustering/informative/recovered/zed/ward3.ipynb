# %%
from src import analysis

# %%
analysis.inf_cluster_ward_recovered("C:\\Users\\VLAD\\prog\\Data-Imputation-and-Clustering-Analysis\\out\\recovered_zet\\small\\3.xlsx")
# Out:
# === Кластер 0 (n=10314) ===
#
# ЧИСЛОВЫЕ ПРИЗНАКИ (describe):
#               count          mean            std   min      25%      50%  \
# price       10314.0   6791.672337    9187.263146  41.0   1452.0   2807.5
# total_cost  10314.0  75819.274404  101978.418597  87.0  14055.0  30152.0
#
#                      75%       max
# price        7385.206474   70635.0
# total_cost  92854.000000  746580.0
#
# КАТЕГОРИАЛЬНЫЕ ПРИЗНАКИ (top значения):
#
# store_name:
# store_name
# Finn Flare (ТРЦ Охта Молл)    1034
# Gloria Jeans (ТРЦ Галерея)    1029
# O'STIN (ТРЦ Галерея)           997
# Name: count, dtype: int64
#
# brands:
# brands
# Mango        465
# H&M          460
# Pull&Bear    457
# Name: count, dtype: int64
#
# cards_number:
# cards_number
# 2221004951988549    18
# 4040009528719679    13
# 4210006135009358    12
# Name: count, dtype: Int64
#
# === Кластер 1 (n=8493) ===
#
# ЧИСЛОВЫЕ ПРИЗНАКИ (describe):
# ...
