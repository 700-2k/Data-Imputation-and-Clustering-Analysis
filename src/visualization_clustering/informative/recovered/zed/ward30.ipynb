# %%
from src import analysis

# %%
analysis.inf_cluster_ward_recovered("C:\\Users\\VLAD\\prog\\Data-Imputation-and-Clustering-Analysis\\out\\recovered_zet\\small\\30.xlsx")
# Out:
# === Кластер 0 (n=10558) ===
#
# ЧИСЛОВЫЕ ПРИЗНАКИ (describe):
#               count          mean            std    min      25%  \
# price       10558.0   6905.597132    8736.522544   45.0   1940.0
# total_cost  10558.0  81982.197682  105931.204617  180.0  16984.0
#
#                      50%            75%       max
# price        3707.672993    7732.466792   74531.0
# total_cost  34891.000000  107627.000000  746580.0
#
# КАТЕГОРИАЛЬНЫЕ ПРИЗНАКИ (top значения):
#
# store_name:
# store_name
# O'STIN (ТРЦ Галерея)          1098
# Finn Flare (ТРЦ Охта Молл)     978
# Gloria Jeans (ТРЦ Галерея)     963
# Name: count, dtype: int64
#
# brands:
# brands
# Sony    617
# Zara    601
# H&M     550
# Name: count, dtype: int64
#
# cards_number:
# cards_number
# 2200009855731946    406
# 2228003003412194     79
# 5200004525164559     49
# Name: count, dtype: Int64
#
# === Кластер 1 (n=8292) ===
#
# ЧИСЛОВЫЕ ПРИЗНАКИ (describe):
# ...
