# %%
from src import analysis

# %%
analysis.inf_cluster_ward_recovered("C:\\Users\\VLAD\\prog\\Data-Imputation-and-Clustering-Analysis\\out\\recovered_zet\\small\\10.xlsx")
# Out:
# === Кластер 0 (n=10355) ===
#
# ЧИСЛОВЫЕ ПРИЗНАКИ (describe):
#               count          mean            std    min           25%  \
# price       10355.0   6843.081317    9093.074323   39.0   1598.671232
# total_cost  10355.0  76992.522170  102331.408442  229.0  14749.000000
#
#                 50%      75%       max
# price        3082.0   7348.0   69572.0
# total_cost  31237.0  95659.5  746580.0
#
# КАТЕГОРИАЛЬНЫЕ ПРИЗНАКИ (top значения):
#
# store_name:
# store_name
# Finn Flare (ТРЦ Охта Молл)    1024
# Gloria Jeans (ТРЦ Галерея)    1018
# O'STIN (ТРЦ Галерея)          1012
# Name: count, dtype: int64
#
# brands:
# brands
# Pull&Bear    506
# Mango        490
# Zara         470
# Name: count, dtype: int64
#
# cards_number:
# cards_number
# 2200007911731001    49
# 2221004951988549    33
# 4180003550139709    25
# Name: count, dtype: Int64
#
# === Кластер 1 (n=8439) ===
#
# ЧИСЛОВЫЕ ПРИЗНАКИ (describe):
# ...
