# %%
from src import analysis

# %%
analysis.inf_cluster_ward_recovered("C:\\Users\\VLAD\\prog\\Data-Imputation-and-Clustering-Analysis\\out\\recovered_groups\\small\\30.xlsx")
# Out:
# === Кластер 0 (n=14157) ===
#
# ЧИСЛОВЫЕ ПРИЗНАКИ (describe):
#               count          mean           std   min     25%      50%  \
# price       14157.0   4576.110146   8040.903975  27.0   927.0   1245.0
# total_cost  14157.0  57499.329766  94627.050864  56.0  6192.0  16984.0
#
#                 75%       max
# price        3594.0   68762.0
# total_cost  53330.0  746580.0
#
# КАТЕГОРИАЛЬНЫЕ ПРИЗНАКИ (top значения):
#
# store_name:
# store_name
# ВкусВилл (ул. Олеко Дундича, 33)    1587
# Finn Flare (ТРЦ Охта Молл)           990
# Gloria Jeans (ТРЦ Галерея)           971
# Name: count, dtype: int64
#
# brands:
# brands
# Nike     4211
# H&M       371
# Mango     366
# Name: count, dtype: int64
#
# cards_number:
# cards_number
# 2200001074737236    2117
# 4230004559962882       6
# 4270005562213519       6
# Name: count, dtype: Int64
#
# === Кластер 1 (n=7352) ===
#
# ЧИСЛОВЫЕ ПРИЗНАКИ (describe):
#              count        mean          std   min    25%     50%      75%  \
# ...
