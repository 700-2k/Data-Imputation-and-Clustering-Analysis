# %%
from src import analysis

# %%
analysis.inf_cluster_ward_recovered("C:\\Users\\VLAD\\prog\\Data-Imputation-and-Clustering-Analysis\\out\\recovered_groups\\small\\3.xlsx")
# Out:
# === Кластер 0 (n=10406) ===
#
# ЧИСЛОВЫЕ ПРИЗНАКИ (describe):
#               count          mean            std    min       25%      50%  \
# price       10406.0   6522.484504    9117.950159   39.0   1310.25   2600.0
# total_cost  10406.0  74521.307227  101010.135424  130.0  13611.00  29247.5
#
#                  75%       max
# price        6827.75   79483.0
# total_cost  91944.25  746580.0
#
# КАТЕГОРИАЛЬНЫЕ ПРИЗНАКИ (top значения):
#
# store_name:
# store_name
# Finn Flare (ТРЦ Охта Молл)    1038
# Gloria Jeans (ТРЦ Галерея)    1029
# O'STIN (ТРЦ Галерея)          1009
# Name: count, dtype: int64
#
# brands:
# brands
# Adidas    533
# Mango     462
# Zara      446
# Name: count, dtype: int64
#
# cards_number:
# cards_number
# 2200001070618658    55
# 5190003627027436     6
# 2200024116070641     6
# Name: count, dtype: Int64
#
# === Кластер 1 (n=7358) ===
#
# ЧИСЛОВЫЕ ПРИЗНАКИ (describe):
#              count         mean          std   min     25%    50%     75%  \
# ...
