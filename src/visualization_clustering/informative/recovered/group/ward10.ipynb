# %%
from src import analysis

# %%
analysis.inf_cluster_ward_recovered("C:\\Users\\VLAD\\prog\\Data-Imputation-and-Clustering-Analysis\\out\\recovered_groups\\small\\10.xlsx")
# Out:
# === Кластер 0 (n=10483) ===
#
# ЧИСЛОВЫЕ ПРИЗНАКИ (describe):
#               count          mean            std   min      25%      50%  \
# price       10483.0   6441.344868    9026.342980  32.0   1210.0   2514.0
# total_cost  10483.0  74349.983306  100659.261034  87.0  13483.0  29278.0
#
#                 75%       max
# price        6581.0   69572.0
# total_cost  91986.0  746580.0
#
# КАТЕГОРИАЛЬНЫЕ ПРИЗНАКИ (top значения):
#
# store_name:
# store_name
# DNS (МЕГА Парнас)             1040
# Gloria Jeans (ТРЦ Галерея)    1026
# Finn Flare (ТРЦ Охта Молл)    1020
# Name: count, dtype: int64
#
# brands:
# brands
# Apple    1312
# H&M       439
# Mango     417
# Name: count, dtype: int64
#
# cards_number:
# cards_number
# 2200001070618658    303
# 4230007392370723      6
# 2200021824251228      6
# Name: count, dtype: Int64
#
# === Кластер 1 (n=6868) ===
#
# ЧИСЛОВЫЕ ПРИЗНАКИ (describe):
#              count         mean          std   min    25%    50%     75%  \
# ...
