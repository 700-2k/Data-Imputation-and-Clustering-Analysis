# %%
from src import analysis

# %%
analysis.inf_cluster_chebyshev("C:\\Users\\VLAD\\prog\\Data-Imputation-and-Clustering-Analysis\\out\\recovered_groups\\small\\20.xlsx")
# Out:
# === Кластер 0 (n=384) ===
#
# ЧИСЛОВЫЕ ПРИЗНАКИ (describe):
#             count           mean           std       min       25%       50%  \
# price       384.0   77699.785156  62153.394066     651.0    2055.5   89290.0
# total_cost  384.0  473225.296875  94719.189847  277705.0  406684.0  455022.0
#
#                   75%       max
# price       126303.50  210705.0
# total_cost  520899.75  746580.0
#
# КАТЕГОРИАЛЬНЫЕ ПРИЗНАКИ (top значения):
#
# store_name:
# store_name
# DNS (МЕГА Парнас)                  115
# restore: (ТРЦ Галерея)              72
# DNS (ТРК Лиговъ, Лиговский 153)     71
# Name: count, dtype: int64
#
# brands:
# brands
# Sony       112
# Xiaomi      33
# Samsung     25
# Name: count, dtype: int64
#
# cards_number:
# cards_number
# 2200001070618658    24
# 2221004156127504     6
# 4270007648768613     6
# Name: count, dtype: Int64
#
# === Кластер 1 (n=44) ===
#
# ЧИСЛОВЫЕ ПРИЗНАКИ (describe):
# ...
