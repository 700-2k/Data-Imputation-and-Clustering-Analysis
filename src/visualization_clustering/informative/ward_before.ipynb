# %%
from src import analysis

# %%
analysis.inf_cluster_ward()
# Out:
# === Кластер 0 (n=9577) ===
#
# ЧИСЛОВЫЕ ПРИЗНАКИ (describe):
#              count          mean            std   min      25%      50%  \
# price       9577.0   7208.780516   10043.456161  46.0   1441.0   2750.0
# total_cost  9577.0  78848.610108  102762.255752  87.0  14604.0  31621.0
#
#                  75%       max
# price         7574.0   73332.0
# total_cost  107527.0  746580.0
#
# КАТЕГОРИАЛЬНЫЕ ПРИЗНАКИ (top значения):
#
# store_name:
# store_name
# Finn Flare (ТРЦ Охта Молл)    967
# Gloria Jeans (ТРЦ Галерея)    965
# O'STIN (ТРЦ Галерея)          936
# Name: count, dtype: int64
#
# brands:
# brands
# Mango     463
# Uniqlo    454
# Zara      452
# Name: count, dtype: int64
#
# cards_number:
# cards_number
# 4210005852635737    6
# 2228007427586650    6
# 4040008210389809    6
# Name: count, dtype: Int64
#
# === Кластер 1 (n=8401) ===
#
# ЧИСЛОВЫЕ ПРИЗНАКИ (describe):
#              count          mean           std   min     25%     50%     75%  \
# ...
