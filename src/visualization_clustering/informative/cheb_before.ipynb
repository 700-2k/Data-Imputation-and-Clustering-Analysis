# %%
from src import analysis

# %%
analysis.inf_cluster_chebyshev()
# Out:
# === Кластер 0 (n=1082) ===
#
# ЧИСЛОВЫЕ ПРИЗНАКИ (describe):
#              count           mean            std      min        25%  \
# price       1082.0  131137.850277   35029.682606  50515.0  106986.25
# total_cost  1082.0  311224.456562  131689.427419  95853.0  208320.50
#
#                  50%       75%       max
# price       127651.0  152017.0  258186.0
# total_cost  293105.0  397418.0  746580.0
#
# КАТЕГОРИАЛЬНЫЕ ПРИЗНАКИ (top значения):
#
# store_name:
# store_name
# DNS (МЕГА Парнас)                  243
# DNS (ТРК Лиговъ, Лиговский 153)    221
# М.Видео (ТРЦ Галерея)              208
# Name: count, dtype: int64
#
# brands:
# brands
# Samsung    138
# Huawei      90
# Sony        77
# Name: count, dtype: int64
#
# cards_number:
# cards_number
# 2224006797178526    5
# 2200005612649946    5
# 2200009855731946    5
# Name: count, dtype: Int64
#
# === Кластер 1 (n=80) ===
#
# ЧИСЛОВЫЕ ПРИЗНАКИ (describe):
# ...
