# %%
from src import analysis

# %%
analysis.cluster_chebyshev()
# Out:
# === Кластер 0 (n=115) ===
#
# ЧИСЛОВЫЕ ПРИЗНАКИ (describe):
#                     count           mean            std       min       25%  \
# price               115.0  222261.165217   31933.384111  171211.0  198615.0
# number_of_products  115.0       4.878261       1.278348       2.0       4.0
# total_cost          115.0  415866.286957  126318.465988  200555.0  326061.0
#
#                          50%       75%       max
# price               219945.0  242075.0  351527.0
# number_of_products       5.0       6.0       6.0
# total_cost          393049.0  489581.0  746580.0
#
# КАТЕГОРИАЛЬНЫЕ ПРИЗНАКИ (top значения):
#
# store_name:
# store_name
# DNS (МЕГА Парнас)                  28
# DNS (ТРК Лиговъ, Лиговский 153)    24
# М.Видео (ТРЦ Галерея)              22
# Name: count, dtype: int64
#
# date-time:
# date-time
# 2024-04-03 20:18:00    2
# 2020-07-27 13:47:00    2
# 2021-07-16 13:19:00    2
# Name: count, dtype: int64
#
# coordinates:
# coordinates
# 30.36064,59.92741      43
# ...
