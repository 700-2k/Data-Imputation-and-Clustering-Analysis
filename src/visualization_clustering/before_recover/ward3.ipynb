# %%
from src import analysis

# %%
analysis.cluster_ward()
# Out:
# === Кластер 0 (n=10149) ===
#
# ЧИСЛОВЫЕ ПРИЗНАКИ (describe):
#                       count          mean            std   min      25%  \
# price               10149.0   6737.432456    9503.658843  29.0   1165.0
# number_of_products  10149.0      4.508129       1.311413   2.0      4.0
# total_cost          10149.0  73312.437974  100901.253341  56.0  12176.0
#
#                         50%      75%       max
# price                2573.0   7302.0   79530.0
# number_of_products      5.0      6.0       6.0
# total_cost          29075.0  91783.0  746580.0
#
# КАТЕГОРИАЛЬНЫЕ ПРИЗНАКИ (top значения):
#
# store_name:
# store_name
# Finn Flare (ТРЦ Охта Молл)    1005
# Gloria Jeans (ТРЦ Галерея)     991
# O'STIN (ТРЦ Галерея)           978
# Name: count, dtype: int64
#
# date-time:
# date-time
# 2024-06-14 19:38:00    10
# 2024-12-29 21:56:00     7
# 2025-05-06 15:09:00     6
# Name: count, dtype: int64
#
# coordinates:
# coordinates
# 30.36064,59.92741      4111
# ...
