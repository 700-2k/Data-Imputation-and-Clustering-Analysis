# %%
from src import analysis

# %%
analysis.inf_cluster_ward()
# Out:
# === Кластер 0 (n=25959) ===
#
# ЧИСЛОВЫЕ ПРИЗНАКИ (describe):
#               count          mean          std   min    25%     50%      75%  \
# total_cost  25959.0  12836.905967  19794.51944  56.0  957.0  4689.0  14682.0
#
#                  max
# total_cost  104115.0
#
# === Кластер 1 (n=2196) ===
#
# ЧИСЛОВЫЕ ПРИЗНАКИ (describe):
#              count           mean           std       min       25%       50%  \
# total_cost  2196.0  163257.734062  36156.963017  104691.0  132529.0  160432.0
#
#                  75%       max
# total_cost  194486.0  229560.0
#
# === Кластер 2 (n=694) ===
#
# ЧИСЛОВЫЕ ПРИЗНАКИ (describe):
#             count           mean           std       min       25%       50%  \
# total_cost  694.0  447872.564841  87685.211579  351464.0  382540.0  421606.5
#
#                  75%       max
# total_cost  492232.0  746580.0
#
# === Кластер 3 (n=1152) ===
#
# ЧИСЛОВЫЕ ПРИЗНАКИ (describe):
# ...
