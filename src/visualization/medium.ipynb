# %%
from src import analysis

# %%
data = analysis.data["medium"]

# %% [markdown]
# # Count mean, median and mode

# %%
data.count()
# Out:
#                          store_name        coordinates            categories  \
# 0                              None               None                  None
# 1                              None               None                  None
# 2  ВкусВилл (ул. Олеко Дундича, 33)  30.36064,59.92741  Термобутылки/шейкеры
#
#    brands        price      cards_number number_of_products receipt_id  \
# 0    None  9536.818927              None            4.49866       None
# 1    None        882.0              None                5.0       None
# 2  Adidas         [92]  2200001022556807                [6]       №453
#
#      total_cost
# 0  42691.867125
# 1        6856.0
# 2         [551]

# %% [markdown]
# # Ananlyse stores feature

# %%
data.draw_hist_store()

# %% [markdown]
# # Analyse date-time feature

# %%
data.draw_hist_date()

# %% [markdown]
# # Analyse coordinates feature

# %%
data.draw_hist_coords()

# %% [markdown]
# # Analyse categories feature

# %%
data.draw_hist_cats()

# %% [markdown]
# # Analyse brands feature

# %%
data.draw_hist_brand()

# %%
data.draw_hist_top_brands()

# %%
data.draw_hist_bottom_brands()

# %% [markdown]
# # Analyse price feature

# %%
data.draw_hist_price()

# %% [markdown]
# # Analyse card number feature

# %%
data.count_unique('cards_number')
# Out:
# count    18758.000000
# mean         3.998454
# std          1.414269
# min          2.000000
# 25%          3.000000
# 50%          4.000000
# 75%          5.000000
# max          6.000000
# Name: count, dtype: float64

# %% [markdown]
# # Analyse number of products feature

# %%
data.draw_hist_num_products()

# %% [markdown]
# # Analyse receipt id feature

# %%
data.analyse_receipt_id()
# Out:
# Unique number: 690, Number of rows: 75003
# Highest number of unique receipt id for stores:
# store_name
# DNS (МЕГА Парнас)                         618
# DNS (ТРК Лиговъ, Лиговский 153)           595
# Finn Flare (ТРЦ Охта Молл)                650
# Gloria Jeans (ТРЦ Галерея)                633
# Hockey Club (Российский пр., 6, стр.1)    636
# Name: receipt_id, dtype: int64

# %% [markdown]
# # Analyse total cost feature

# %%
data.draw_hist_total_cost()
