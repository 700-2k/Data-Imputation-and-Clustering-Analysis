# %%
from src import analysis

# %%
data = analysis.data["large"]

# %% [markdown]
# # Count mean, median and mode

# %%
data.count()
# Out:
#                          store_name        coordinates            categories  \
# 0                              None               None                  None
# 1                              None               None                  None
# 2  Лента (Обводного канала, 118 к7)  30.36064,59.92741  Термобутылки/шейкеры
#
#    brands        price      cards_number number_of_products receipt_id  \
# 0    None  9442.322343              None           4.504642       None
# 1    None        854.0              None                5.0       None
# 2  Adidas         [90]  2200001040013552                [6]       №617
#
#      total_cost
# 0  42570.643889
# 1        6695.0
# 2         [726]

# %% [markdown]
# # Ananlyse stores feature

# %%
data.draw_hist_store()

# %% [markdown]
# # Analyse date-time feature

# %%
data.draw_hist_date()

# %% [markdown]
# # Analyse coordinates feature

# %%
data.draw_hist_coords()

# %% [markdown]
# # Analyse categories feature

# %%
data.draw_hist_cats()

# %% [markdown]
# # Analyse brands feature

# %%
data.draw_hist_brand()

# %%
data.draw_hist_top_brands()

# %%
data.draw_hist_bottom_brands()

# %% [markdown]
# # Analyse price feature

# %%
data.draw_hist_price()

# %% [markdown]
# # Analyse card number feature

# %%
data.count_unique('cards_number')
# Out:
# count    62445.000000
# mean         4.003539
# std          1.416410
# min          2.000000
# 25%          3.000000
# 50%          4.000000
# 75%          5.000000
# max          6.000000
# Name: count, dtype: float64

# %% [markdown]
# # Analyse number of products feature

# %%
data.draw_hist_num_products()

# %% [markdown]
# # Analyse receipt id feature

# %%
data.analyse_receipt_id()
# Out:
# Unique number: 2182, Number of rows: 250001
# Highest number of unique receipt id for stores:
# store_name
# DNS (МЕГА Парнас)                         2123
# DNS (ТРК Лиговъ, Лиговский 153)           2061
# Finn Flare (ТРЦ Охта Молл)                2142
# Gloria Jeans (ТРЦ Галерея)                2117
# Hockey Club (Российский пр., 6, стр.1)    2115
# Name: receipt_id, dtype: int64

# %% [markdown]
# # Analyse total cost feature

# %%
data.draw_hist_total_cost()
